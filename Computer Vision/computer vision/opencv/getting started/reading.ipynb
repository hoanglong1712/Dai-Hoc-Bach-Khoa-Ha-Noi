# %%
# !pip install opencv-python
# !pip install opencv-contrib-python

# %%
# lấy ảnh
# !wget https://upload.wikimedia.org/wikipedia/commons/b/b5/Lion_d%27Afrique.jpg
# Out:
# --2024-03-16 20:05:03--  https://upload.wikimedia.org/wikipedia/commons/b/b5/Lion_d%27Afrique.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12671789 (12M) [image/jpeg]
# Saving to: ‘Lion_d'Afrique.jpg.1’
#
# Lion_d'Afrique.jpg. 100%[===================>]  12.08M  26.3MB/s    in 0.5s
#
# 2024-03-16 20:05:04 (26.3 MB/s) - ‘Lion_d'Afrique.jpg.1’ saved [12671789/12671789]

# %%
import cv2

img = cv2.imread('free-images.jpg')
img2 = cv2.imread('Lion_d\'Afrique.jpg')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Lion_d\'Afrique.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
img = cv2.imread('Lion_d\'Afrique.jpg')
plt.imshow(img)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(rgb_img)
plt.axis('off')
# Out:
# (-0.5, 2747.5, 2994.5, -0.5)

# %%
img = cv2.imread('Lion_d\'Afrique.jpg', cv2.IMREAD_ANYCOLOR)
plt.imshow(img)

# %%
file_name = 'sutu.jpg'
import cv2

cv2.imwrite(file_name, img)

cv2.imwrite('sutu2.jpg', rgb_img)
# Out:
# True
