# %%
face_path  = '/content/drive/MyDrive/Colab Notebooks/computer vision/bai tap/face.png'
mountain_path = '/content/drive/MyDrive/Colab Notebooks/computer vision/bai tap/mountain.png'

# %% [markdown]
# ảnh \\
# face \\
#
# https://drive.google.com/file/d/1bKl9xkvpG5U4mRukPqHq-xmGrjZeOELe/view?usp=sharing
#
# mountain \\
# https://drive.google.com/file/d/1E3PiN24bYfxikFibvur0Dy1u1ekAxNK4/view?usp=sharing

# %%
import cv2
import matplotlib.pyplot as plt

face = cv2.imread(face_path)
plt.imshow(face)

# %%
face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
plt.imshow(face_rgb)

# %%
import cv2
def toHsvAndLab(img_path):
  img = cv2.imread(img_path)
  img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
  img_lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
  return img_hsv, img_lab

# %%
hsv, lab = toHsvAndLab(face_path)

# %%
import  matplotlib.pyplot as plt
plt.imshow(hsv)
#plt.imshow(lab)

# %%
# thay đổi giá trị kênh V thành giá trị lớn nhất
hsv[:, :, 0] = 255
fig = plt.figure(figsize=(10, 7))
rows = 2
columns = 2
fig.add_subplot(rows, columns, 1)
plt.imshow(hsv)
fig.add_subplot(rows, columns, 2)
plt.imshow(lab)

# %%
# thay đổi giá trị kênh L thành giá trị lớn nhất
lab[:, :, 0] = 255
plt.imshow(lab)
