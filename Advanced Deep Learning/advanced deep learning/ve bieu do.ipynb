# %% [markdown]
# https://www.kaggle.com/code/lehoanglonglong/hust-text-summary-fine-tuning
#
# https://www.kaggle.com/code/lehoanglonglong/hust-huan-luyen-bo-sung-tom-tat-van-ban-vit5

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
text = """1000 	0.852500
1500 	0.783500
2000 	0.758700
2500 	0.722900
3000 	0.707600
3500 	0.665000
4000 	0.658200
4500 	0.644600
5000 	0.607400
5500 	0.618500
6000 	0.602900
6500 	0.570400
7000 	0.560300
7500 	0.559700
8000 	0.533100
8500 	0.547300
9000 	0.524600
9500 	0.513300
10000 	0.513100
10500 	0.501500
11000 	0.492000
11500 	0.494600
12000 	0.485600
12500 	0.478100
13000 	0.474800
13500 	0.470300
14000 	0.470600
14500 	0.462600
15000 	0.465600
15500 	0.45580
3500 	0.453500
4000 	0.456400
4500 	0.443700
5000 	0.424800
5500 	0.414300
6000 	0.410800
6500 	0.415600
7000 	0.393000
7500 	0.385900
8000 	0.382600
8500 	0.374300
9000 	0.357500
9500 	0.371300
10000 	0.358600
10500 	0.344800
11000 	0.353600
11500 	0.342200
12000 	0.337600
12500 	0.331100
13000 	0.333600
13500 	0.328700
14000 	0.333100
14500 	0.323500
15000 	0.319800
15500 	0.322300"""
ar = []
for item in text.split('\n'):
  ar.append(float(item.split()[1]))
  pass

# %%
data = np.array(ar)
plt.plot(data, label='Training Loss')
plt.title("Training Loss")
plt.xlabel("Half of Epochs")
plt.ylabel("Loss")
plt.grid(True)
plt.legend(loc='best')
plt.show()
